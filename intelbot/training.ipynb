# %%
import random
import json
import numpy as np
import pickle

import nltk
from nltk.stem import WordNetLemmatizer

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD

lemmatizer = WordNetLemmatizer()

intents = json.loads(open('intents.json').read())

words = []
classes = []
documents = []
ignore_letters = ['?', '!', '.', ',']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        documents.append(((word_list), intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(word)
         for word in words if word not in ignore_letters]
words = sorted(set(words))

classes = sorted(set(classes))

pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

# training = []
# output_empty = [0] * len(classes)

# for document in documents:
#     bag = []
#     word_patterns = document[0]
#     word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
#     for word in words:
#         bag.append(1) if word in word_patterns else bag.append(0)

#     output_row = list(output_empty)
#     output_row[classes.index(document[1])] = 1
#     training.append([bag, output_row])

# random.shuffle(training)
# training = np.array(training)

# train_x = list(training[:, 0])
# train_y = list(training[:, 1])

training = []
output_empty = [0] * len(classes)

for document in documents:
    bag = []
    word_patterns = document[0]
    word_patterns = [lemmatizer.lemmatize(
        word.lower()) for word in word_patterns]

    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(document[1])] = 1

    training.append([bag, output_row])

# Shuffle the training data
random.shuffle(training)

# Convert training data to NumPy arrays
train_x = np.array([sample[0] for sample in training])
train_y = np.array([sample[1] for sample in training])

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]), ), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',
              optimizer=sgd, metrics=['accuracy'])

hist = model.fit(np.array(train_x), np.array(train_y),
                 epochs=200, batch_size=5, verbose=1)
# model.save('chatbotmodel.h5', hist)
model.save('chatbotmodel.keras')
print('Done')
# Out:
# WARNING:tensorflow:From c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/200
# WARNING:tensorflow:From c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 31/31 [==============================] - 2s 5ms/step - loss: 3.6265 - accuracy: 0.0325
# Epoch 2/200
# 31/31 [==============================] - 0s 4ms/step - loss: 3.5625 - accuracy: 0.0325
# Epoch 3/200
# 31/31 [==============================] - 0s 4ms/step - loss: 3.5176 - accuracy: 0.0844
# Epoch 4/200
# 31/31 [==============================] - 0s 4ms/step - loss: 3.4302 - accuracy: 0.1364
# Epoch 5/200
# 31/31 [==============================] - 0s 4ms/step - loss: 3.3411 - accuracy: 0.1039
# Epoch 6/200
# 31/31 [==============================] - 0s 4ms/step - loss: 3.2872 - accuracy: 0.1494
# Epoch 7/200
# 31/31 [==============================] - 0s 4ms/step - loss: 3.1219 - accuracy: 0.1623
# Epoch 8/200
# 31/31 [==============================] - 0s 4ms/step - loss: 3.0095 - accuracy: 0.2403
# Epoch 9/200
# 31/31 [==============================] - 0s 4ms/step - loss: 2.8473 - accuracy: 0.2792
# Epoch 10/200
# 31/31 [==============================] - 0s 4ms/step - loss: 2.6699 - accuracy: 0.3117
# Epoch 11/200
# 31/31 [==============================] - 0s 4ms/step - loss: 2.6055 - accuracy: 0.2922
# Epoch 12/200
# 31/31 [==============================] - 0s 3ms/step - loss: 2.4185 - accuracy: 0.3571
# Epoch 13/200
# 31/31 [==============================] - 0s 3ms/step - loss: 2.3186 - accuracy: 0.3377
# Epoch 14/200
# 31/31 [==============================] - 0s 3ms/step - loss: 2.0955 - accuracy: 0.4091
# Epoch 15/200
# 31/31 [==============================] - 0s 2ms/step - loss: 2.0297 - accuracy: 0.4610
# Epoch 16/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.8444 - accuracy: 0.4740
# Epoch 17/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.7614 - accuracy: 0.5000
# Epoch 18/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.7017 - accuracy: 0.5130
# Epoch 19/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.4546 - accuracy: 0.5779
# Epoch 20/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.4177 - accuracy: 0.5714
# Epoch 21/200
# 31/31 [==============================] - 0s 3ms/step - loss: 1.4879 - accuracy: 0.5455
# Epoch 22/200
# 31/31 [==============================] - 0s 4ms/step - loss: 1.4919 - accuracy: 0.5974
# Epoch 23/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.3067 - accuracy: 0.6039
# Epoch 24/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.2994 - accuracy: 0.6818
# Epoch 25/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0271 - accuracy: 0.6948
# Epoch 26/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.0778 - accuracy: 0.6429
# Epoch 27/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1490 - accuracy: 0.6429
# Epoch 28/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1842 - accuracy: 0.6623
# Epoch 29/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9852 - accuracy: 0.7013
# Epoch 30/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8716 - accuracy: 0.7662
# Epoch 31/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.9254 - accuracy: 0.6558
# Epoch 32/200
# 31/31 [==============================] - 0s 2ms/step - loss: 1.1371 - accuracy: 0.6688
# Epoch 33/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8536 - accuracy: 0.7403
# Epoch 34/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6868 - accuracy: 0.8117
# Epoch 35/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8032 - accuracy: 0.7532
# Epoch 36/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.8052
# Epoch 37/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.7554 - accuracy: 0.7857
# Epoch 38/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.8097 - accuracy: 0.7662
# Epoch 39/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5795 - accuracy: 0.8571
# Epoch 40/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6878 - accuracy: 0.7727
# Epoch 41/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5755 - accuracy: 0.8636
# Epoch 42/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6198 - accuracy: 0.7857
# Epoch 43/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.5354 - accuracy: 0.8571
# Epoch 44/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.6322 - accuracy: 0.7662
# Epoch 45/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6226 - accuracy: 0.8052
# Epoch 46/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5177 - accuracy: 0.8636
# Epoch 47/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4898 - accuracy: 0.8442
# Epoch 48/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5284 - accuracy: 0.8182
# Epoch 49/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.5784 - accuracy: 0.8377
# Epoch 50/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6089 - accuracy: 0.8182
# Epoch 51/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4570 - accuracy: 0.8766
# Epoch 52/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4600 - accuracy: 0.8377
# Epoch 53/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3984 - accuracy: 0.8571
# Epoch 54/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4652 - accuracy: 0.8506
# Epoch 55/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.4450 - accuracy: 0.8571
# Epoch 56/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4192 - accuracy: 0.8961
# Epoch 57/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3998 - accuracy: 0.8961
# Epoch 58/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4777 - accuracy: 0.8766
# Epoch 59/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3686 - accuracy: 0.8896
# Epoch 60/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3876 - accuracy: 0.9026
# Epoch 61/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4225 - accuracy: 0.8636
# Epoch 62/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3505 - accuracy: 0.9026
# Epoch 63/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3687 - accuracy: 0.8896
# Epoch 64/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4479 - accuracy: 0.8571
# Epoch 65/200
# 31/31 [==============================] - 0s 6ms/step - loss: 0.4735 - accuracy: 0.8442
# Epoch 66/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4425 - accuracy: 0.8636
# Epoch 67/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4538 - accuracy: 0.8377
# Epoch 68/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4240 - accuracy: 0.8766
# Epoch 69/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2539 - accuracy: 0.9156
# Epoch 70/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3473 - accuracy: 0.8961
# Epoch 71/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.4480 - accuracy: 0.8377
# Epoch 72/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3873 - accuracy: 0.8701
# Epoch 73/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2952 - accuracy: 0.9156
# Epoch 74/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2904 - accuracy: 0.8961
# Epoch 75/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2468 - accuracy: 0.9481
# Epoch 76/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3515 - accuracy: 0.8961
# Epoch 77/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3575 - accuracy: 0.8896
# Epoch 78/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3376 - accuracy: 0.8961
# Epoch 79/200
# 31/31 [==============================] - 0s 5ms/step - loss: 0.4926 - accuracy: 0.8377
# Epoch 80/200
# 31/31 [==============================] - 0s 5ms/step - loss: 0.4035 - accuracy: 0.8571
# Epoch 81/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3259 - accuracy: 0.8961
# Epoch 82/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2737 - accuracy: 0.9026
# Epoch 83/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3628 - accuracy: 0.8961
# Epoch 84/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3319 - accuracy: 0.9026
# Epoch 85/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2714 - accuracy: 0.9026
# Epoch 86/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3238 - accuracy: 0.9091
# Epoch 87/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3458 - accuracy: 0.8961
# Epoch 88/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.4184 - accuracy: 0.8506
# Epoch 89/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3115 - accuracy: 0.9156
# Epoch 90/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2713 - accuracy: 0.9481
# Epoch 91/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2405 - accuracy: 0.9286
# Epoch 92/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2900 - accuracy: 0.9091
# Epoch 93/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2785 - accuracy: 0.9221
# Epoch 94/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2320 - accuracy: 0.9286
# Epoch 95/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2671 - accuracy: 0.9156
# Epoch 96/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2044 - accuracy: 0.9351
# Epoch 97/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2794 - accuracy: 0.9091
# Epoch 98/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3026 - accuracy: 0.9026
# Epoch 99/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2099 - accuracy: 0.9481
# Epoch 100/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3127 - accuracy: 0.8961
# Epoch 101/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2596 - accuracy: 0.9156
# Epoch 102/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2661 - accuracy: 0.9416
# Epoch 103/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2771 - accuracy: 0.9286
# Epoch 104/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2412 - accuracy: 0.9026
# Epoch 105/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3009 - accuracy: 0.8831
# Epoch 106/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2085 - accuracy: 0.9416
# Epoch 107/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2361 - accuracy: 0.9286
# Epoch 108/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1972 - accuracy: 0.9416
# Epoch 109/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2556 - accuracy: 0.9156
# Epoch 110/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3038 - accuracy: 0.8896
# Epoch 111/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1682 - accuracy: 0.9416
# Epoch 112/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2276 - accuracy: 0.9221
# Epoch 113/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2569 - accuracy: 0.9221
# Epoch 114/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1833 - accuracy: 0.9545
# Epoch 115/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2331 - accuracy: 0.9156
# Epoch 116/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2163 - accuracy: 0.9545
# Epoch 117/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1691 - accuracy: 0.9481
# Epoch 118/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2671 - accuracy: 0.9091
# Epoch 119/200
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2877 - accuracy: 0.8896
# Epoch 120/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2037 - accuracy: 0.9351
# Epoch 121/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2131 - accuracy: 0.9286
# Epoch 122/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2548 - accuracy: 0.9156
# Epoch 123/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1783 - accuracy: 0.9416
# Epoch 124/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2562 - accuracy: 0.9026
# Epoch 125/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2422 - accuracy: 0.9091
# Epoch 126/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2925 - accuracy: 0.9091
# Epoch 127/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2301 - accuracy: 0.9286
# Epoch 128/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2218 - accuracy: 0.9286
# Epoch 129/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2234 - accuracy: 0.9091
# Epoch 130/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1998 - accuracy: 0.9351
# Epoch 131/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2253 - accuracy: 0.9286
# Epoch 132/200
# 31/31 [==============================] - 0s 6ms/step - loss: 0.1929 - accuracy: 0.9481
# Epoch 133/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1912 - accuracy: 0.9286
# Epoch 134/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3438 - accuracy: 0.9156
# Epoch 135/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1394 - accuracy: 0.9610
# Epoch 136/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2507 - accuracy: 0.9221
# Epoch 137/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1970 - accuracy: 0.9416
# Epoch 138/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1592 - accuracy: 0.9610
# Epoch 139/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2242 - accuracy: 0.9351
# Epoch 140/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3244 - accuracy: 0.9026
# Epoch 141/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2461 - accuracy: 0.9416
# Epoch 142/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2748 - accuracy: 0.9156
# Epoch 143/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2189 - accuracy: 0.9221
# Epoch 144/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2668 - accuracy: 0.8831
# Epoch 145/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1708 - accuracy: 0.9416
# Epoch 146/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1762 - accuracy: 0.9286
# Epoch 147/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1146 - accuracy: 0.9610
# Epoch 148/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1297 - accuracy: 0.9610
# Epoch 149/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2070 - accuracy: 0.9351
# Epoch 150/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1924 - accuracy: 0.9545
# Epoch 151/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2113 - accuracy: 0.9351
# Epoch 152/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2188 - accuracy: 0.9221
# Epoch 153/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.3159 - accuracy: 0.9156
# Epoch 154/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2112 - accuracy: 0.9286
# Epoch 155/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1579 - accuracy: 0.9545
# Epoch 156/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1840 - accuracy: 0.9545
# Epoch 157/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1562 - accuracy: 0.9416
# Epoch 158/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2364 - accuracy: 0.9545
# Epoch 159/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1868 - accuracy: 0.9416
# Epoch 160/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1415 - accuracy: 0.9545
# Epoch 161/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.1204 - accuracy: 0.9740
# Epoch 162/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2201 - accuracy: 0.9351
# Epoch 163/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2102 - accuracy: 0.9221
# Epoch 164/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1868 - accuracy: 0.9481
# Epoch 165/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2011 - accuracy: 0.9481
# Epoch 166/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2920 - accuracy: 0.9156
# Epoch 167/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2210 - accuracy: 0.9221
# Epoch 168/200
# 31/31 [==============================] - 0s 3ms/step - loss: 0.2017 - accuracy: 0.9545
# Epoch 169/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1422 - accuracy: 0.9545
# Epoch 170/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1338 - accuracy: 0.9481
# Epoch 171/200
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1679 - accuracy: 0.9481
# Epoch 172/200
# 31/31 [==============================] - 0s 5ms/step - loss: 0.2132 - accuracy: 0.9091
# Epoch 173/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2380 - accuracy: 0.9351
# Epoch 174/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1917 - accuracy: 0.9481
# Epoch 175/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2282 - accuracy: 0.9156
# Epoch 176/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.3016 - accuracy: 0.8831
# Epoch 177/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1791 - accuracy: 0.9416
# Epoch 178/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2367 - accuracy: 0.9026
# Epoch 179/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1646 - accuracy: 0.9351
# Epoch 180/200
# 31/31 [==============================] - 0s 8ms/step - loss: 0.1471 - accuracy: 0.9481
# Epoch 181/200
# 31/31 [==============================] - 0s 6ms/step - loss: 0.2623 - accuracy: 0.9416
# Epoch 182/200
# 31/31 [==============================] - 0s 6ms/step - loss: 0.2059 - accuracy: 0.9221
# Epoch 183/200
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1790 - accuracy: 0.9481
# Epoch 184/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2096 - accuracy: 0.9286
# Epoch 185/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1730 - accuracy: 0.9545
# Epoch 186/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1921 - accuracy: 0.9286
# Epoch 187/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1963 - accuracy: 0.9481
# Epoch 188/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2135 - accuracy: 0.9351
# Epoch 189/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1384 - accuracy: 0.9610
# Epoch 190/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.2069 - accuracy: 0.9351
# Epoch 191/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1575 - accuracy: 0.9481
# Epoch 192/200
# 31/31 [==============================] - 0s 4ms/step - loss: 0.1309 - accuracy: 0.9545
# Epoch 193/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1169 - accuracy: 0.9610
# Epoch 194/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1363 - accuracy: 0.9675
# Epoch 195/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1596 - accuracy: 0.9416
# Epoch 196/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2354 - accuracy: 0.9221
# Epoch 197/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1604 - accuracy: 0.9481
# Epoch 198/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1892 - accuracy: 0.9286
# Epoch 199/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1611 - accuracy: 0.9286
# Epoch 200/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1810 - accuracy: 0.9286
# Done
